# %%
import pandas as pd

# %%
my_list = ['NVDA','MFST','FD','AMZN','BA']
my_list
# Out:
# ['NVDA', 'MFST', 'FD', 'AMZN', 'BA']

# %%
type(my_list)
# Out:
# list

# %%
series = pd.Series(data = my_list)
series
# Out:
# 0    NVDA
# 1    MFST
# 2      FD
# 3    AMZN
# 4      BA
# dtype: object

# %%
type(series)
# Out:
# pandas.core.series.Series

# %%
series1 = pd.Series(data = [100, 200, 500, 1000, 5000])
series1
# Out:
# 0     100
# 1     200
# 2     500
# 3    1000
# 4    5000
# dtype: int64

# %%
my_series = pd.Series(data = ['Stranger Things','Prison Break','Family Man'])
my_series
# Out:
# 0    Stranger Things
# 1       Prison Break
# 2         Family Man
# dtype: object

# %%
type(my_series)
# Out:
# pandas.core.series.Series

# %% [markdown]
# series with custom index

# %%
my_list = ['NVDA','MFST','FB','AMZN','BA']
my_list
# Out:
# ['NVDA', 'MFST', 'FB', 'AMZN', 'BA']

# %%
my_labels = ['stock#1','stock#2','stock#3','stock#4','stock#5']
my_labels
# Out:
# ['stock#1', 'stock#2', 'stock#3', 'stock#4', 'stock#5']

# %%
series_1 = pd.Series(data = my_list, index = my_labels)
series_1
# Out:
# stock#1    NVDA
# stock#2    MFST
# stock#3      FB
# stock#4    AMZN
# stock#5      BA
# dtype: object

# %%
my_list = ['Stranger Things','Prison Break','Family Man']
my_labels = ['S1','S2','S3']
series = pd.Series(data = my_list, index = my_labels)
series
# Out:
# S1    Stranger Things
# S2       Prison Break
# S3         Family Man
# dtype: object

# %% [markdown]
# from dictionary

# %%
my_dict = {'Bank Client ID': 111,
          'Bank Client Name': 'Bob',
          'Net Worth[rs]': 800000,
          'Years with Bank': 10}
my_dict
# Out:
# {'Bank Client ID': 111,
#  'Bank Client Name': 'Bob',
#  'Net Worth[rs]': 800000,
#  'Years with Bank': 10}

# %%
type(my_dict)
# Out:
# dict

# %%
series_2 = pd.Series(my_dict)
series_2
# Out:
# Bank Client ID         111
# Bank Client Name       Bob
# Net Worth[rs]       800000
# Years with Bank         10
# dtype: object

# %%
stocks = {'NVDA': 400,
          'AMZN': 600,
          'FB': 200}
stocks
# Out:
# {'NVDA': 400, 'AMZN': 600, 'FB': 200}

# %%
series_3 = pd.Series(stocks)
series_3
# Out:
# NVDA    400
# AMZN    600
# FB      200
# dtype: int64

# %% [markdown]
# attributes

# %%
my_list = ['NVDA','MSFT','FB','AMZN','BA']
my_series = pd.Series( my_list)
my_series
# Out:
# 0    NVDA
# 1    MSFT
# 2      FB
# 3    AMZN
# 4      BA
# dtype: object

# %%
my_series.values
# Out:
# array(['NVDA', 'MSFT', 'FB', 'AMZN', 'BA'], dtype=object)

# %%
my_series.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
my_series.is_unique
# Out:
# True

# %%
my_series.shape
# Out:
# (5,)

# %%
my_series.size
# Out:
# 5

# %%
my_series = pd.Series(data = [100,200,500,1000,5000])
my_series
# Out:
# 0     100
# 1     200
# 2     500
# 3    1000
# 4    5000
# dtype: int64

# %%
my_series.sum()
# Out:
# np.int64(6800)

# %%
my_series.product()
# Out:
# np.int64(50000000000000)

# %%
my_series.mean()
# Out:
# np.float64(1360.0)

# %%
my_series.head(4)
# Out:
# 0     100
# 1     200
# 2     500
# 3    1000
# dtype: int64

# %%
new_series = my_series.head(3)
new_series
# Out:
# 0    100
# 1    200
# 2    500
# dtype: int64

# %%
my_series.tail(2)
# Out:
# 3    1000
# 4    5000
# dtype: int64

# %%
my_series.memory_usage()
# Out:
# 172

# %%
sp = pd.read_csv('S_P500_Prices.csv') 
sp
# Out:
#             sp500
# 0     1295.500000
# 1     1289.089966
# 2     1293.670044
# 3     1308.040039
# 4     1314.500000
# ...           ...
# 2154  3327.770020
# 2155  3349.159912
# 2156  3351.280029
# 2157  3360.469971
# 2158  3333.689941
#
# [2159 rows x 1 columns]

# %%
type(sp)
# Out:
# pandas.core.frame.DataFrame

# %%
my_series = pd.Series(data = [-10,100,-30,50,100])
my_series
# Out:
# 0    -10
# 1    100
# 2    -30
# 3     50
# 4    100
# dtype: int64

# %%
abs(my_series) #everthing +ve
# Out:
# 0     10
# 1    100
# 2     30
# 3     50
# 4    100
# dtype: int64

# %%
set(my_series) #deletes duplicates
# Out:
# {-30, -10, 50, 100}

# %% [markdown]
# sorting and ordering

# %%
sp = pd.read_csv('S_P500_Prices.csv')
sp = sp.iloc[:, 0] #1d df to series
sp
# Out:
# 0       1295.500000
# 1       1289.089966
# 2       1293.670044
# 3       1308.040039
# 4       1314.500000
#            ...
# 2154    3327.770020
# 2155    3349.159912
# 2156    3351.280029
# 2157    3360.469971
# 2158    3333.689941
# Name: sp500, Length: 2159, dtype: float64

# %%
type(sp)
# Out:
# pandas.core.series.Series

# %%
sp.sort_values()
# Out:
# 97      1278.040039
# 98      1278.180054
# 99      1285.500000
# 1       1289.089966
# 2       1293.670044
#            ...
# 2038    3373.229980
# 2034    3373.939941
# 2033    3379.449951
# 2035    3380.159912
# 2037    3386.149902
# Name: sp500, Length: 2159, dtype: float64

# %%
sp.sort_index(inplace = True)
sp
# Out:
# 0       1295.500000
# 1       1289.089966
# 2       1293.670044
# 3       1308.040039
# 4       1314.500000
#            ...
# 2154    3327.770020
# 2155    3349.159912
# 2156    3351.280029
# 2157    3360.469971
# 2158    3333.689941
# Name: sp500, Length: 2159, dtype: float64

# %%
sp = pd.read_csv('S_P500_Prices.csv')
sp = sp.iloc[:, 0] 
sp
# Out:
# 0       1295.500000
# 1       1289.089966
# 2       1293.670044
# 3       1308.040039
# 4       1314.500000
#            ...
# 2154    3327.770020
# 2155    3349.159912
# 2156    3351.280029
# 2157    3360.469971
# 2158    3333.689941
# Name: sp500, Length: 2159, dtype: float64

# %%
sp.sum()
# Out:
# np.float64(4790280.287214)

# %%
sp.count()
# Out:
# np.int64(2159)

# %%
sp.max()
# Out:
# 3386.149902

# %%
sp.min()
# Out:
# 1278.040039

# %%
sp.describe() #all statistical data
# Out:
# count    2159.000000
# mean     2218.749554
# std       537.321727
# min      1278.040039
# 25%      1847.984985
# 50%      2106.629883
# 75%      2705.810059
# max      3386.149902
# Name: sp500, dtype: float64

# %%
sp.mean()
# Out:
# np.float64(2218.7495540592868)

# %%
sp.median()
# Out:
# 2106.629883

# %%
sp.sum()/sp.count()
# Out:
# np.float64(2218.7495540592868)

# %%
sp = pd.read_csv('S_P500_Prices.csv')
sp = sp.iloc[:, 0] #1d df to series
sp
# Out:
# 0       1295.500000
# 1       1289.089966
# 2       1293.670044
# 3       1308.040039
# 4       1314.500000
#            ...
# 2154    3327.770020
# 2155    3349.159912
# 2156    3351.280029
# 2157    3360.469971
# 2158    3333.689941
# Name: sp500, Length: 2159, dtype: float64

# %%
1295.5000 in sp.values
# Out:
# True

# %%
1295.5 in sp.index
# Out:
# False

# %%
1295.5 in sp #look for index and not values
# Out:
# False

# %%
3349 in sp
# Out:
# False

# %%
3349.15 in sp.values
# Out:
# False

# %%
sp = round(sp) #roundoffs the numbers 
sp
# Out:
# 0       1296.0
# 1       1289.0
# 2       1294.0
# 3       1308.0
# 4       1314.0
#          ...
# 2154    3328.0
# 2155    3349.0
# 2156    3351.0
# 2157    3360.0
# 2158    3334.0
# Name: sp500, Length: 2159, dtype: float64

# %%
3349 in sp
# Out:
# False

# %%
3349 in sp.values
# Out:
# True

# %%
sp = pd.read_csv('S_P500_Prices.csv')
sp = sp.iloc[:, 0] #1d df to series
sp
# Out:
# 0       1295.500000
# 1       1289.089966
# 2       1293.670044
# 3       1308.040039
# 4       1314.500000
#            ...
# 2154    3327.770020
# 2155    3349.159912
# 2156    3351.280029
# 2157    3360.469971
# 2158    3333.689941
# Name: sp500, Length: 2159, dtype: float64

# %%
sp[0]
# Out:
# np.float64(1295.5)

# %%
sp[899]
# Out:
# np.float64(2084.070068)

# %%
sp[2158]
# Out:
# np.float64(3333.689941)

# %%
sp[4] #fifth element
# Out:
# np.float64(1315.380005)

# %%
sp = pd.read_csv('S_P500_Prices.csv')
sp = sp.iloc[:,0]
sp
# Out:
# 0       1295.500000
# 1       1289.089966
# 2       1293.670044
# 3       1308.040039
# 4       1314.500000
#            ...
# 2154    3327.770020
# 2155    3349.159912
# 2156    3351.280029
# 2157    3360.469971
# 2158    3333.689941
# Name: sp500, Length: 2159, dtype: float64

# %%
sp[0:5]
# Out:
# 0    1295.500000
# 1    1289.089966
# 2    1293.670044
# 3    1308.040039
# 4    1314.500000
# Name: sp500, dtype: float64

# %%
sp[:10]
# Out:
# 0    1295.500000
# 1    1289.089966
# 2    1293.670044
# 3    1308.040039
# 4    1314.500000
# 5    1315.380005
# 6    1316.000000
# 7    1314.650024
# 8    1326.060059
# 9    1318.430054
# Name: sp500, dtype: float64

# %%
sp[5:]
# Out:
# 5       1315.380005
# 6       1316.000000
# 7       1314.650024
# 8       1326.060059
# 9       1318.430054
#            ...
# 2154    3327.770020
# 2155    3349.159912
# 2156    3351.280029
# 2157    3360.469971
# 2158    3333.689941
# Name: sp500, Length: 2154, dtype: float64

# %%
sp[:-6]
# Out:
# 0       1295.500000
# 1       1289.089966
# 2       1293.670044
# 3       1308.040039
# 4       1314.500000
#            ...
# 2148    3218.439941
# 2149    3258.439941
# 2150    3246.219971
# 2151    3271.120117
# 2152    3294.610107
# Name: sp500, Length: 2153, dtype: float64
